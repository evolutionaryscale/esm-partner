# %%
# Install esm and other dependencies
! pip install boto3
! pip install esm
! pip install py3Dmol
! pip install matplotlib
! pip install dna-features-viewer
# Out:
# Requirement already satisfied: boto3 in /Users/cram/src/esm-partner/.venv/lib/python3.13/site-packages (1.37.12)
# Requirement already satisfied: botocore<1.38.0,>=1.37.12 in /Users/cram/src/esm-partner/.venv/lib/python3.13/site-packages (from boto3) (1.37.12)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /Users/cram/src/esm-partner/.venv/lib/python3.13/site-packages (from boto3) (1.0.1)
# Requirement already satisfied: s3transfer<0.12.0,>=0.11.0 in /Users/cram/src/esm-partner/.venv/lib/python3.13/site-packages (from boto3) (0.11.4)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /Users/cram/src/esm-partner/.venv/lib/python3.13/site-packages (from botocore<1.38.0,>=1.37.12->boto3) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /Users/cram/src/esm-partner/.venv/lib/python3.13/site-packages (from botocore<1.38.0,>=1.37.12->boto3) (2.3.0)
# Requirement already satisfied: six>=1.5 in /Users/cram/src/esm-partner/.venv/lib/python3.13/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.38.0,>=1.37.12->boto3) (1.17.0)
# Requirement already satisfied: esm in /Users/cram/src/esm-partner/.venv/lib/python3.13/site-packages (3.1.6)
# Requirement already satisfied: torch>=2.2.0 in /Users/cram/src/esm-partner/.venv/lib/python3.13/site-packages (from esm) (2.6.0)
# Requirement already satisfied: torchvision in /Users/cram/src/esm-partner/.venv/lib/python3.13/site-packages (from esm) (0.21.0)
# Requirement already satisfied: torchtext in /Users/cram/src/esm-partner/.venv/lib/python3.13/site-packages (from esm) (0.6.0)
# Requirement already satisfied: transformers<4.48.2 in /Users/cram/src/esm-partner/.venv/lib/python3.13/site-packages (from esm) (4.48.1)
# Requirement already satisfied: ipython in /Users/cram/src/esm-partner/.venv/lib/python3.13/site-packages (from esm) (9.0.2)
# Requirement already satisfied: einops in /Users/cram/src/esm-partner/.venv/lib/python3.13/site-packages (from esm) (0.8.1)
# Requirement already satisfied: biotite==0.41.2 in /Users/cram/src/esm-partner/.venv/lib/python3.13/site-packages (from esm) (0.41.2)
# Requirement already satisfied: msgpack-numpy in /Users/cram/src/esm-partner/.venv/lib/python3.13/site-packages (from esm) (0.4.8)
# Requirement already satisfied: biopython in /Users/cram/src/esm-partner/.venv/lib/python3.13/site-packages (from esm) (1.85)
# Requirement already satisfied: scikit-learn in /Users/cram/src/esm-partner/.venv/lib/python3.13/site-packages (from esm) (1.6.1)
# Requirement already satisfied: brotli in /Users/cram/src/esm-partner/.venv/lib/python3.13/site-packages (from esm) (1.1.0)
# Requirement already satisfied: attrs in /Users/cram/src/esm-partner/.venv/lib/python3.13/site-packages (from esm) (25.3.0)
# Requirement already satisfied: pandas in /Users/cram/src/esm-partner/.venv/lib/python3.13/site-packages (from esm) (2.2.3)
# Requirement already satisfied: cloudpathlib in /Users/cram/src/esm-partner/.venv/lib/python3.13/site-packages (from esm) (0.21.0)
# Requirement already satisfied: tenacity in /Users/cram/src/esm-partner/.venv/lib/python3.13/site-packages (from esm) (9.0.0)
# Requirement already satisfied: zstd in /Users/cram/src/esm-partner/.venv/lib/python3.13/site-packages (from esm) (1.5.6.6)
# Requirement already satisfied: msgpack>=0.5.6 in /Users/cram/src/esm-partner/.venv/lib/python3.13/site-packages (from biotite==0.41.2->esm) (1.1.0)
# Requirement already satisfied: networkx>=2.0 in /Users/cram/src/esm-partner/.venv/lib/python3.13/site-packages (from biotite==0.41.2->esm) (3.4.2)
# Requirement already satisfied: numpy<2.0,>=1.14.5 in /Users/cram/src/esm-partner/.venv/lib/python3.13/site-packages (from biotite==0.41.2->esm) (1.26.4)
# Requirement already satisfied: requests>=2.12 in /Users/cram/src/esm-partner/.venv/lib/python3.13/site-packages (from biotite==0.41.2->esm) (2.32.3)
# Requirement already satisfied: filelock in /Users/cram/src/esm-partner/.venv/lib/python3.13/site-packages (from torch>=2.2.0->esm) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/cram/src/esm-partner/.venv/lib/python3.13/site-packages (from torch>=2.2.0->esm) (4.12.2)
# Requirement already satisfied: jinja2 in /Users/cram/src/esm-partner/.venv/lib/python3.13/site-packages (from torch>=2.2.0->esm) (3.1.6)
# Requirement already satisfied: fsspec in /Users/cram/src/esm-partner/.venv/lib/python3.13/site-packages (from torch>=2.2.0->esm) (2025.3.0)
# Requirement already satisfied: setuptools in /Users/cram/src/esm-partner/.venv/lib/python3.13/site-packages (from torch>=2.2.0->esm) (76.0.0)
# Requirement already satisfied: sympy==1.13.1 in /Users/cram/src/esm-partner/.venv/lib/python3.13/site-packages (from torch>=2.2.0->esm) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/cram/src/esm-partner/.venv/lib/python3.13/site-packages (from sympy==1.13.1->torch>=2.2.0->esm) (1.3.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /Users/cram/src/esm-partner/.venv/lib/python3.13/site-packages (from transformers<4.48.2->esm) (0.29.3)
# Requirement already satisfied: packaging>=20.0 in /Users/cram/src/esm-partner/.venv/lib/python3.13/site-packages (from transformers<4.48.2->esm) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /Users/cram/src/esm-partner/.venv/lib/python3.13/site-packages (from transformers<4.48.2->esm) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /Users/cram/src/esm-partner/.venv/lib/python3.13/site-packages (from transformers<4.48.2->esm) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /Users/cram/src/esm-partner/.venv/lib/python3.13/site-packages (from transformers<4.48.2->esm) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.1 in /Users/cram/src/esm-partner/.venv/lib/python3.13/site-packages (from transformers<4.48.2->esm) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /Users/cram/src/esm-partner/.venv/lib/python3.13/site-packages (from transformers<4.48.2->esm) (4.67.1)
# Requirement already satisfied: decorator in /Users/cram/src/esm-partner/.venv/lib/python3.13/site-packages (from ipython->esm) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in /Users/cram/src/esm-partner/.venv/lib/python3.13/site-packages (from ipython->esm) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/cram/src/esm-partner/.venv/lib/python3.13/site-packages (from ipython->esm) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /Users/cram/src/esm-partner/.venv/lib/python3.13/site-packages (from ipython->esm) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /Users/cram/src/esm-partner/.venv/lib/python3.13/site-packages (from ipython->esm) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /Users/cram/src/esm-partner/.venv/lib/python3.13/site-packages (from ipython->esm) (3.0.50)
# Requirement already satisfied: pygments>=2.4.0 in /Users/cram/src/esm-partner/.venv/lib/python3.13/site-packages (from ipython->esm) (2.19.1)
# Requirement already satisfied: stack_data in /Users/cram/src/esm-partner/.venv/lib/python3.13/site-packages (from ipython->esm) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in /Users/cram/src/esm-partner/.venv/lib/python3.13/site-packages (from ipython->esm) (5.14.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/cram/src/esm-partner/.venv/lib/python3.13/site-packages (from pandas->esm) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/cram/src/esm-partner/.venv/lib/python3.13/site-packages (from pandas->esm) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/cram/src/esm-partner/.venv/lib/python3.13/site-packages (from pandas->esm) (2025.1)
# Requirement already satisfied: scipy>=1.6.0 in /Users/cram/src/esm-partner/.venv/lib/python3.13/site-packages (from scikit-learn->esm) (1.15.2)
# Requirement already satisfied: joblib>=1.2.0 in /Users/cram/src/esm-partner/.venv/lib/python3.13/site-packages (from scikit-learn->esm) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/cram/src/esm-partner/.venv/lib/python3.13/site-packages (from scikit-learn->esm) (3.6.0)
# Requirement already satisfied: six in /Users/cram/src/esm-partner/.venv/lib/python3.13/site-packages (from torchtext->esm) (1.17.0)
# Requirement already satisfied: sentencepiece in /Users/cram/src/esm-partner/.venv/lib/python3.13/site-packages (from torchtext->esm) (0.2.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /Users/cram/src/esm-partner/.venv/lib/python3.13/site-packages (from torchvision->esm) (11.1.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/cram/src/esm-partner/.venv/lib/python3.13/site-packages (from jedi>=0.16->ipython->esm) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/cram/src/esm-partner/.venv/lib/python3.13/site-packages (from pexpect>4.3->ipython->esm) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/cram/src/esm-partner/.venv/lib/python3.13/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython->esm) (0.2.13)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/cram/src/esm-partner/.venv/lib/python3.13/site-packages (from requests>=2.12->biotite==0.41.2->esm) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/cram/src/esm-partner/.venv/lib/python3.13/site-packages (from requests>=2.12->biotite==0.41.2->esm) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/cram/src/esm-partner/.venv/lib/python3.13/site-packages (from requests>=2.12->biotite==0.41.2->esm) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/cram/src/esm-partner/.venv/lib/python3.13/site-packages (from requests>=2.12->biotite==0.41.2->esm) (2025.1.31)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/cram/src/esm-partner/.venv/lib/python3.13/site-packages (from jinja2->torch>=2.2.0->esm) (3.0.2)
# Requirement already satisfied: executing>=1.2.0 in /Users/cram/src/esm-partner/.venv/lib/python3.13/site-packages (from stack_data->ipython->esm) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/cram/src/esm-partner/.venv/lib/python3.13/site-packages (from stack_data->ipython->esm) (3.0.0)
# Requirement already satisfied: pure-eval in /Users/cram/src/esm-partner/.venv/lib/python3.13/site-packages (from stack_data->ipython->esm) (0.2.3)
# Requirement already satisfied: py3Dmol in /Users/cram/src/esm-partner/.venv/lib/python3.13/site-packages (2.4.2)
# Requirement already satisfied: matplotlib in /Users/cram/src/esm-partner/.venv/lib/python3.13/site-packages (3.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/cram/src/esm-partner/.venv/lib/python3.13/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /Users/cram/src/esm-partner/.venv/lib/python3.13/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/cram/src/esm-partner/.venv/lib/python3.13/site-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/cram/src/esm-partner/.venv/lib/python3.13/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /Users/cram/src/esm-partner/.venv/lib/python3.13/site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /Users/cram/src/esm-partner/.venv/lib/python3.13/site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /Users/cram/src/esm-partner/.venv/lib/python3.13/site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/cram/src/esm-partner/.venv/lib/python3.13/site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/cram/src/esm-partner/.venv/lib/python3.13/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/cram/src/esm-partner/.venv/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: dna-features-viewer in /Users/cram/src/esm-partner/.venv/lib/python3.13/site-packages (3.1.3)
# Requirement already satisfied: matplotlib>=3 in /Users/cram/src/esm-partner/.venv/lib/python3.13/site-packages (from dna-features-viewer) (3.10.1)
# Requirement already satisfied: Biopython in /Users/cram/src/esm-partner/.venv/lib/python3.13/site-packages (from dna-features-viewer) (1.85)
# Requirement already satisfied: packaging in /Users/cram/src/esm-partner/.venv/lib/python3.13/site-packages (from dna-features-viewer) (24.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/cram/src/esm-partner/.venv/lib/python3.13/site-packages (from matplotlib>=3->dna-features-viewer) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /Users/cram/src/esm-partner/.venv/lib/python3.13/site-packages (from matplotlib>=3->dna-features-viewer) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/cram/src/esm-partner/.venv/lib/python3.13/site-packages (from matplotlib>=3->dna-features-viewer) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/cram/src/esm-partner/.venv/lib/python3.13/site-packages (from matplotlib>=3->dna-features-viewer) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /Users/cram/src/esm-partner/.venv/lib/python3.13/site-packages (from matplotlib>=3->dna-features-viewer) (1.26.4)
# Requirement already satisfied: pillow>=8 in /Users/cram/src/esm-partner/.venv/lib/python3.13/site-packages (from matplotlib>=3->dna-features-viewer) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/cram/src/esm-partner/.venv/lib/python3.13/site-packages (from matplotlib>=3->dna-features-viewer) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/cram/src/esm-partner/.venv/lib/python3.13/site-packages (from matplotlib>=3->dna-features-viewer) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/cram/src/esm-partner/.venv/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib>=3->dna-features-viewer) (1.17.0)

# %%
# https://us-east-2.console.aws.amazon.com/sagemaker/home?region=us-east-2#/endpoints
SAGE_ENDPOINT_NAME = "Endpoint-ESMC-300M-1"
# % aws sagemaker list-models
MODEL_NAME = "Model-bmoXsOIIZB3p"

# %%
import boto3
boto3.setup_default_session(region_name='us-east-2', profile_name='partner-prem-dev')

# %%
from esm.sdk.sagemaker import ESM3SageMakerClient
from esm.sdk.api import ESMProtein, LogitsConfig

sagemaker_client = ESM3SageMakerClient(
   # E.g. "Endpoint-ESMC-6B-1"
   endpoint_name=SAGE_ENDPOINT_NAME,
   # E.g. "esmc-6b-2024-12". Same model names as in Forge.
   model=MODEL_NAME
)

protein = ESMProtein(sequence="AAAAA")
protein_tensor = sagemaker_client.encode(protein)
logits_output = sagemaker_client.logits(
   protein_tensor, LogitsConfig(sequence=True, return_embeddings=True)
)
print(logits_output.logits, logits_output.embeddings)
# Out:
# ---------------------------------------------------------------------------
# ModelError                                Traceback (most recent call last)
# File ~/src/esm-partner/.venv/lib/python3.13/site-packages/esm/sdk/sagemaker.py:94, in ESM3SageMakerClient._post(self, endpoint, request, potential_sequence_of_concern)
#      93 try:
# ---> 94     response = self._client.invoke_endpoint(
#      95         EndpointName=self._endpoint_name,
#      96         ContentType="application/json",
#      97         Body=json.dumps(invocations_request),
#      98     )
#      99 except Exception as e:
#
# File ~/src/esm-partner/.venv/lib/python3.13/site-packages/botocore/client.py:570, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     569 # The "self" in this scope is referring to the BaseClient.
# --> 570 return self._make_api_call(operation_name, kwargs)
#
# File ~/src/esm-partner/.venv/lib/python3.13/site-packages/botocore/context.py:124, in with_current_context.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     123     hook()
# --> 124 return func(*args, **kwargs)
#
# File ~/src/esm-partner/.venv/lib/python3.13/site-packages/botocore/client.py:1031, in BaseClient._make_api_call(self, operation_name, api_params)
#    1030     error_class = self.exceptions.from_code(error_code)
# -> 1031     raise error_class(parsed_response, operation_name)
#    1032 else:
#
# ModelError: An error occurred (ModelError) when calling the InvokeEndpoint operation: Received client error (422) from primary and could not load the entire response body. See https://us-east-2.console.aws.amazon.com/cloudwatch/home?region=us-east-2#logEventViewer:group=/aws/sagemaker/Endpoints/Endpoint-ESMC-300M-1 in account 577638386256 for more information.
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[21], line 12
#       4 sagemaker_client = ESM3SageMakerClient(
#       5    # E.g. "Endpoint-ESMC-6B-1"
#       6    endpoint_name=SAGE_ENDPOINT_NAME,
#       7    # E.g. "esmc-6b-2024-12". Same model names as in Forge.
#       8    model=MODEL_NAME
#       9 )
#      11 protein = ESMProtein(sequence="AAAAA")
# ---> 12 protein_tensor = sagemaker_client.encode(protein)
#      13 logits_output = sagemaker_client.logits(
#      14    protein_tensor, LogitsConfig(sequence=True, return_embeddings=True)
#      15 )
#      16 print(logits_output.logits, logits_output.embeddings)
#
# File ~/src/esm-partner/.venv/lib/python3.13/site-packages/esm/sdk/forge.py:243, in ESM3ForgeInferenceClient.retry_decorator.<locals>.wrapper(instance, *args, **kwargs)
#     232 retry_decorator = retry(
#     233     retry=retry_if_result(retry_if_specific_error),
#     234     wait=wait_exponential(
#    (...)    240     before_sleep=log_retry_attempt,
#     241 )
#     242 # Apply the retry decorator to the function
# --> 243 return retry_decorator(func)(instance, *args, **kwargs)
#
# File ~/src/esm-partner/.venv/lib/python3.13/site-packages/tenacity/__init__.py:336, in BaseRetrying.wraps.<locals>.wrapped_f(*args, **kw)
#     334 copy = self.copy()
#     335 wrapped_f.statistics = copy.statistics  # type: ignore[attr-defined]
# --> 336 return copy(f, *args, **kw)
#
# File ~/src/esm-partner/.venv/lib/python3.13/site-packages/tenacity/__init__.py:475, in Retrying.__call__(self, fn, *args, **kwargs)
#     473 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     474 while True:
# --> 475     do = self.iter(retry_state=retry_state)
#     476     if isinstance(do, DoAttempt):
#     477         try:
#
# File ~/src/esm-partner/.venv/lib/python3.13/site-packages/tenacity/__init__.py:376, in BaseRetrying.iter(self, retry_state)
#     374 result = None
#     375 for action in self.iter_state.actions:
# --> 376     result = action(retry_state)
#     377 return result
#
# File ~/src/esm-partner/.venv/lib/python3.13/site-packages/tenacity/__init__.py:398, in BaseRetrying._post_retry_check_actions.<locals>.<lambda>(rs)
#     396 def _post_retry_check_actions(self, retry_state: "RetryCallState") -> None:
#     397     if not (self.iter_state.is_explicit_retry or self.iter_state.retry_run_result):
# --> 398         self._add_action_func(lambda rs: rs.outcome.result())
#     399         return
#     401     if self.after is not None:
#
# File /opt/homebrew/Cellar/python@3.13/3.13.2/Frameworks/Python.framework/Versions/3.13/lib/python3.13/concurrent/futures/_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File /opt/homebrew/Cellar/python@3.13/3.13.2/Frameworks/Python.framework/Versions/3.13/lib/python3.13/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~/src/esm-partner/.venv/lib/python3.13/site-packages/tenacity/__init__.py:478, in Retrying.__call__(self, fn, *args, **kwargs)
#     476 if isinstance(do, DoAttempt):
#     477     try:
# --> 478         result = fn(*args, **kwargs)
#     479     except BaseException:  # noqa: B902
#     480         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File ~/src/esm-partner/.venv/lib/python3.13/site-packages/esm/sdk/forge.py:502, in ESM3ForgeInferenceClient.encode(self, input)
#     499 request = {"inputs": tracks, "model": self.model}
#     501 try:
# --> 502     data = self._post("encode", request, input.potential_sequence_of_concern)
#     503 except ESMProteinError as e:
#     504     return e
#
# File ~/src/esm-partner/.venv/lib/python3.13/site-packages/esm/sdk/sagemaker.py:100, in ESM3SageMakerClient._post(self, endpoint, request, potential_sequence_of_concern)
#      94     response = self._client.invoke_endpoint(
#      95         EndpointName=self._endpoint_name,
#      96         ContentType="application/json",
#      97         Body=json.dumps(invocations_request),
#      98     )
#      99 except Exception as e:
# --> 100     raise RuntimeError(f"Failure in {endpoint}: {e}")
#     102 data = json.loads(response["Body"].read().decode())
#     104 # Response must match request.
#
# RuntimeError: Failure in encode: An error occurred (ModelError) when calling the InvokeEndpoint operation: Received client error (422) from primary and could not load the entire response body. See https://us-east-2.console.aws.amazon.com/cloudwatch/home?region=us-east-2#logEventViewer:group=/aws/sagemaker/Endpoints/Endpoint-ESMC-300M-1 in account 577638386256 for more information.

# %%
from esm.sdk.sagemaker import ESM3SageMakerClient
from esm.sdk.api import ESMProtein, LogitsConfig

sagemaker_client = ESM3SageMakerClient(
   # E.g. "Endpoint-ESMC-6B-1"
   endpoint_name=SAGE_ENDPOINT_NAME,
   # E.g. "esmc-6b-2024-12". Same model names as in Forge.
   model=MODEL_NAME
)

protein = ESMProtein(sequence="AAAAA")
protein_tensor = sagemaker_client.encode(protein)
logits_output = sagemaker_client.logits(
   protein_tensor, LogitsConfig(sequence=True, return_embeddings=True)
)
print(logits_output.logits, logits_output.embeddings)
